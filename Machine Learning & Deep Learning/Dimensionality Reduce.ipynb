# %% [markdown]
# # Dimensionality Reduction

# %% [markdown]
# # 1. Motivation
# - High-dimensional data can be difficult to visualize and analyze.
# - It's impossible to visualize data in more than 3 dimensions.
# - High-dimensional data can lead to the "**curse of dimensionality**", where the volume of the space increases exponentially with the number of dimensions, making data sparse and harder to analyze.
#
# ## 1.1 The curse of dimensionality
# - As the number of dimensions increases, the amount of data needed to maintain a given level of statistical significance grows exponentially.
#   - In high-dimensional spaces(e.g. 10000D), most of data point($>99.99%$) are close to the boundary of the space, making it difficult to find meaningful patterns.
# - This can lead to overfitting, where a model learns the noise in the training data rather than the underlying patterns.
# - It can also lead to increased computational complexity and storage requirements.

# %% [markdown]
# # 2. Methods of Dimensionality Reduction
#
# ## 2.1 Projection
# - **Projection** is a simple method of dimensionality reduction where data is projected onto a lower-dimensional subspace.
# - It involves finding a lower-dimensional representation of the data that preserves as much information as possible.
# - Common examples include:
#   - **Principal Component Analysis (PCA)**: Finds the directions of maximum variance in the data and projects onto them.
#   - **Linear Discriminant Analysis (LDA)**: Projects data onto directions that maximize class separability.
#
# ## 2.2 Manifold Learning
# - **Manifold Learning** is a non-linear dimensionality reduction technique that assumes data lies on a low-dimensional manifold embedded in a higher-dimensional space.
# - It aims to uncover the underlying structure of the data by learning the manifold.
# - Common examples include:
#   - **t-Distributed Stochastic Neighbor Embedding (t-SNE)**: Preserves local structure of the data while reducing dimensionality.
#   - **Isomap**: Preserves global geometric structure of the data by using geodesic distances.
#   - **Locally Linear Embedding (LLE)**: Preserves local relationships between data points.
#
# ## 2.3 Principal Component Analysis (PCA)
# - **Principal Component Analysis (PCA)** is a linear dimensionality reduction technique that finds the directions of maximum variance in the data.
#   - Mathematically, PCA rotates the coordinate system of the data so that the first $k$ principal components capture the most variance, then projects the data onto these components to reduce dimensionality.
# - It projects the data onto a lower-dimensional subspace while preserving as much variance as possible.
# - PCA is widely used in data preprocessing, feature extraction, and visualization.
# - The steps involved in PCA include:
#   1. Standardize the data.
#   2. Compute the covariance matrix of the data.
#   3. Compute the eigenvalues and eigenvectors of the covariance matrix.
#   4. Sort the eigenvalues and select the top k eigenvectors to form a new subspace.
#   5. Project the original data onto the new subspace to obtain the reduced-dimensional representation.
#
# ### Principal Components:
# The principal components are the eigenvectors of the covariance matrix, and they represent **the directions of maximum variance** in the data. The corresponding eigenvalues indicate the amount of variance captured by each principal component. The first principal component captures the most variance, the second captures the second most, and so on.
#
#
# ### Convariance:
# Convariance is to measure how much two random variables change together. It is defined as:
# $$Cov(X, Y) = E[(X - E[X])(Y - E[Y])]$$
# - A positive covariance indicates that the two variables tend to increase or decrease together
# - A negative covariance indicates that they tend to move in opposite directions.
# - A covariance of zero indicates that the two variables are independent.
#
# ### Covariance Matrix:
# The covariance matrix is a square matrix that contains the covariances between pairs of variables. For a dataset with $n$ features, the covariance matrix is an $n x n$ matrix where
# $$
# COV_{ij} = Cov(X_i, X_j)
# $$
# The covariance matrix is symmetric and positive semi-definite, and it plays a crucial role in PCA as it captures the variance and relationships between the features in the data.
#
# ## 2.4 Locally Linear Embedding (LLE)
# **1. Definition & Category**
# *   **LLE** is a non-linear dimensionality reduction technique.
# *   It belongs to the family of **Manifold Learning** algorithms.
# *   **Goal:** To map high-dimensional data into a low-dimensional space while preserving the intrinsic geometric structure of the data.
#
# **2. Core Philosophy**
# *   **"Local Linearity, Global Non-linearity":** LLE assumes that while the overall data structure may be complex and curved (non-linear), small local neighborhoods of data points are approximately flat (linear).
# *   **Analogy:** Think of a crumpled piece of paper. Globally it is curved, but if you zoom in on any tiny spot, it looks flat. LLE tries to "unfold" this paper while keeping the local relationships intact.
#
# **3. The 3-Step Algorithm**
# LLE works in three distinct stages:
#
# *   **Step 1: Find Neighbors**
#     *   For each data point, identify its $k$ nearest neighbors (using Euclidean distance).
#     *   This defines the local geometry around each point.
# *   **Step 2: Reconstruct with Weights**
#     *   Calculate a set of optimal **weights** ($W$) that best reconstructs each point as a linear combination of its neighbors.
#     *   The goal is to minimize the reconstruction error: $\epsilon(W) = \sum_i |x_i - \sum_j W_{ij}x_j|^2$.
#     *   These weights capture the local geometric properties.
# *   **Step 3: Low-Dimensional Embedding**
#     *   Map the data to a low-dimensional space (e.g., 2D or 3D).
#     *   **Crucial Step:** Keep the **weights** ($W$) fixed (from Step 2) and find new coordinates ($y$) that minimize the reconstruction error using the *same* weights.
#     *   This ensures that the local relationships learned in high dimensions are preserved in the low-dimensional map.
#
# **4. Pros & Cons**
#
# | **Pros** | **Cons** |
# | :--- | :--- |
# | Can handle complex non-linear structures (e.g., Swiss Roll) that PCA cannot. | Sensitive to the choice of neighbor parameter **$k$**. |
# | Preserves local topology and intrinsic structure effectively. | Computationally expensive for very large datasets ($O(N^2)$). |
# | No local minima problem (solved via eigenvalue decomposition). | Sensitive to noise and non-uniform sampling density. |
#
# **5. Comparison with PCA**
# *   **PCA (Projection):** Focuses on **global** variance. It projects data onto a lower-dimensional plane (like a shadow). It fails if the data is on a curved manifold.
# *   **LLE (Manifold Learning):** Focuses on **local** relationships. It "unfolds" the data. It is superior for data that lies on a twisted or curved surface.
#
# **6. Common Applications**
# *   Image processing (e.g., face recognition).
# *   Data visualization (visualizing high-dimensional clusters in 2D/3D).
# *   Bioinformatics (analyzing gene expression patterns).
#
# ## 2.5 t-Distributed Stochastic Neighbor Embedding (t-SNE)
#
# The **core idea** of t-SNE is "If two points are close in the high-dimensional space, they should also be close in the low-dimensional space." Here are the steps involved in t-SNE:
#
# 1. **Compute pairwise similarities**: For each pair of data points in the high-dimensional space, compute a similarity measure (often using a Gaussian distribution) that reflects how close the points are to each other.
# 2. **Define a similar measure in the low-dimensional space**: In the low-dimensional space, define a similar measure (often using a Student's t-distribution) to capture the similarities between points.
# 3. **Minimize the Kullback-Leibler divergence**: Use an optimization algorithm to minimize the Kullback-Leibler divergence between the two distributions (the high-dimensional similarities and the low-dimensional similarities). This ensures that the local structure of the data is preserved in the low-dimensional
